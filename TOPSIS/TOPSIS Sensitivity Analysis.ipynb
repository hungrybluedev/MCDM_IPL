# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
plt.rcParams["figure.dpi"] = 1000
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = '8'

# %%
target = 'batsmen'

# %%
ranking_data = pd.read_csv(target + '_ranks.csv')
ranking_data
# Out:
#      AB de Villiers  Andre Russel  Ben Stokes  Chris Gayle  Chris Lynn  \
# 0                 6             3          15            4           7
# 1                 5             2          13            8          12
# 2                 4             3          16            6           7
# 3                 4             6          16            5           7
# 4                 2             3          16            5           8
# ..              ...           ...         ...          ...         ...
# 995               4             2          14            7          11
# 996               4             3          15            6           9
# 997               4             1          15            3           7
# 998               3             2          15            8           9
# 999               5             2          16            4           6
#
#      David Warner  Faf Du Plessis  Jonny Bairstow  Jos Buttler  \
# 0               1              10               2           12
# 1               1              10               4           14
# 2               1              10               2           12
# 3               1               9               2           10
# 4               1               9               6           12
# ..            ...             ...             ...          ...
# 995             1              10               6           13
# 996             1              11               2           13
# 997             2              11               6           12
# 998             1              12               4           13
# 999             1               8               9           11
#
#      Kane Williamson  Kieron Pollard  Marcus Stoinis  Moeen Ali  \
# 0                 16               9              11         14
# 1                 16               3               6         15
# 2                 15               9              11         14
# 3                 15              12              14         13
# 4                 15              10              13         14
# ..               ...             ...             ...        ...
# 995               16               5               8         15
# 996               16               7               8         14
# 997               16               9              10         14
# 998               16               5               6         14
# 999               15              12              14         13
#
#      Quinton de Kock  Shane Watson  Steve Smith
# 0                  5             8           13
# 1                  7             9           11
# 2                  5             8           13
# 3                  3             8           11
# 4                  4             7           11
# ..               ...           ...          ...
# 995                3             9           12
# 996                5            10           12
# 997                5             8           13
# 998                7            11           10
# 999                3             7           10
#
# [1000 rows x 16 columns]

# %%
x = ranking_data.columns

plt.xticks(rotation='vertical')
plt.yticks(ticks=range(1, len(x) + 1))

plt.xlabel('Batsmen' if target == 'batsmen' else 'Bowlers')
plt.ylabel('Rank')

for _, row in ranking_data.iterrows():
    plt.scatter(x=x, y=list(row), alpha=0.002, c='black')
