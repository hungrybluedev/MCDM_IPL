# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
plt.rcParams["figure.dpi"] = 1000
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = '8'

# %%
target = 'bowlers'

# %%
ranking_data = pd.read_csv(target + '_ranks.csv')
ranking_data
# Out:
#      Andre Russell  Ben Stokes  Chris Morris  Dwayne Bravo  Imran Tahir  \
# 0                8          14            10             9            1
# 1                6          14             9            10            1
# 2                7          14             9            10            1
# 3                6          14            10             9            1
# 4                6          14             9            11            1
# ..             ...         ...           ...           ...          ...
# 995              6          14             8             9            1
# 996              6          14             9            10            1
# 997              6          14             9             8            1
# 998              6          14             8            10            1
# 999              6          14             8             9            1
#
#      Jofra Archer  Kagiso Rabada  Keemo Paul  Lasith Malinga  Moeen Ali  \
# 0               6              2          13               3         11
# 1               8              2          13               3         11
# 2               6              2          13               4         11
# 3               8              2          13               3         12
# 4               7              2          13               3         10
# ..            ...            ...         ...             ...        ...
# 995             7              2          13               4         12
# 996             8              2          13               3         11
# 997             7              2          13               4         11
# 998             7              2          13               3         11
# 999             7              2          13               4         10
#
#      Mohammad Nabi  Rashid Khan  Sam Curran  Sunil Narine  Trent Boult
# 0                5            4           7            12           15
# 1                5            4           7            12           15
# 2                5            3           8            12           15
# 3                5            4           7            11           15
# 4                5            4           8            12           15
# ..             ...          ...         ...           ...          ...
# 995              5            3          10            11           15
# 996              5            4           7            12           15
# 997              5            3          10            12           15
# 998              5            4           9            12           15
# 999              5            3          12            11           15
#
# [1000 rows x 15 columns]

# %%
x = ranking_data.columns

plt.xticks(rotation='vertical')
plt.yticks(ticks=range(1, len(x) + 1))

plt.xlabel('Batsmen' if target == 'batsmen' else 'Bowlers')
plt.ylabel('Rank')

for _, row in ranking_data.iterrows():
    plt.scatter(x=x, y=list(row), alpha=0.002, c='black')
